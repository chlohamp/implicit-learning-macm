# %%
"""
Script to find studies with activation in ROIs. 
- Loads the NiMARE Dataset from derivatives/neurosynth_terms_dataset.pkl.gz
- Identifies studies that have activation in 9 ROIs (by mask overlap)
- Outputs a CSV file with the selected study IDs and metadata to derivatives/macm/lCaud33_studies.csv
"""

import os
import os.path as op
import nibabel as nib
from nilearn.image import threshold_img
import numpy as np
import csv
from nimare.dataset import Dataset

# %%
def binarize(img, z_thresh=2.33, clust_thresh=10):
    
    data = np.asarray(img.dataobj)
    uniq = np.unique(data[np.isfinite(data)])
    if np.all(np.isin(uniq, [0, 1])) and uniq.size <= 2:
        return img
    thr = threshold_img(img, threshold=z_thresh, cluster_threshold=clust_thresh)
    data = (thr.get_fdata() > 0).astype(np.int16)
    return nib.Nifti1Image(data, thr.affine, thr.header)

# %%
# Set up paths for notebook execution (no __file__)
PROJECT_DIR = os.getcwd()
DERIVATIVES_DIR = op.join(PROJECT_DIR, "derivatives")
DSET_PATH = op.join(DERIVATIVES_DIR, "neurosynth_terms_dataset.pkl.gz")
ROI_DIR = op.join(PROJECT_DIR, "dset", "ROIs")
OUT_ROOT = op.join(DERIVATIVES_DIR, "macm")

print(f"\tLoading dataset: {DSET_PATH}", flush=True)
dset = Dataset.load(DSET_PATH)

# %%
roi_files = [f for f in os.listdir(ROI_DIR) if f.endswith('.nii') or f.endswith('.nii.gz')]
for roi_file in roi_files:
    roi_path = op.join(ROI_DIR, roi_file)
    roi_img = binarize(nib.load(roi_path))
    mask = roi_img.get_fdata().astype(bool)
    csv_path = op.join(roi_out_dir, f"{roi_stem}_studies.csv")
    if csv_path and os.path.exists(csv_path):
        print(f"\tCSV already exists at: {csv_path}.")
        
    else:
        print(f"\tFinding studies with activation in {roi_file}...", flush=True)
        study_ids = dset.ids
        selected_ids = []
        coords_df = dset.coordinates
        coords_by_id = {sid: group[["x", "y", "z"]].values for sid, group in coords_df.groupby("id")}
        for sid in study_ids:
            coords = coords_by_id.get(sid, np.empty((0, 3)))
            found = False
            for c in coords:
                ijk = np.round(np.linalg.inv(roi_img.affine) @ np.append(c[:3], 1)).astype(int)[:3]
                if (0 <= ijk[0] < mask.shape[0] and 0 <= ijk[1] < mask.shape[1] and 0 <= ijk[2] < mask.shape[2]):
                    if mask[tuple(ijk)]:
                        found = True
                        break
            if found:
                selected_ids.append(sid)
        print(f"\tFound {len(selected_ids)} studies with {roi_file}.", flush=True)
        if not selected_ids:
            print(f"\tNo studies found with {roi_file}. Skipping.", flush=True)
            continue

        # Output selected study IDs and metadata to CSV in respective folder
        roi_stem = roi_file.replace('.nii.gz', '').replace('.nii', '')
        roi_out_dir = op.join(OUT_ROOT, roi_stem)
        os.makedirs(roi_out_dir, exist_ok=True)

        with open(csv_path, "w", newline="") as csvfile:
            writer = csv.writer(csvfile)
            header = ["id"]
            meta_fields = []
            if hasattr(dset, "metadata") and dset.metadata is not None and not dset.metadata.empty:
                meta_fields = list(sorted({k for md in dset.metadata.to_dict('records') for k in md}))
                header += meta_fields
            writer.writerow(header)
            for sid in selected_ids:
                row = [sid]
                if meta_fields:
                    md_row = dset.metadata.loc[dset.metadata['id'] == sid]
                    if not md_row.empty:
                        md = md_row.iloc[0].to_dict()
                        row += [md.get(f, "") for f in meta_fields]
                    else:
                        row += ["" for _ in meta_fields]
                writer.writerow(row)
        print(f"\tWrote selected study IDs and metadata to: {csv_path}", flush=True)
        print(f"\tSelected: {len(selected_ids)} studies written to CSV for {roi_file}.", flush=True)
# Out:
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.
# 	CSV already exists at: /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv.

# %%
import pandas as pd
import os
import os.path as op

# Directory where the CSVs are saved
macm_dir = op.join(os.getcwd(), "derivatives", "macm")

# Find all ROI subfolders
roi_folders = [f for f in os.listdir(macm_dir) if op.isdir(op.join(macm_dir, f))]

# Load each CSV into a dictionary
roi_csvs = {}
for roi in roi_folders:
    csv_path = op.join(macm_dir, roi, f"{roi}_studies.csv")
    if op.exists(csv_path):
        df = pd.read_csv(csv_path)
        roi_csvs[roi] = df
        print(f"Loaded {csv_path} with {len(df)} rows.")
    else:
        print(f"CSV not found for ROI: {roi}")

print(roi_csvs)
# roi_csvs is a dictionary: key=ROI name, value=DataFrame
# Out:
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rCaud31/rCaud31_studies.csv with 546 rows.
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/lMDN/lMDN_studies.csv with 400 rows.
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/PFC/PFC_studies.csv with 1076 rows.
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rIFGtri1/rIFGtri1_studies.csv with 274 rows.
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rGPi/rGPi_studies.csv with 318 rows.
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/lIFGop7/lIFGop7_studies.csv with 173 rows.
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/lGPi/lGPi_studies.csv with 310 rows.
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/rMDN/rMDN_studies.csv with 483 rows.
# Loaded /Users/chloehampson/Desktop/implicit-learning-macm/derivatives/macm/lCaud33/lCaud33_studies.csv with 307 rows.
# {'rCaud31':              id                                            authors  \
# 0    10639391-1  Victor JD, Apkarian P, Hirsch J, Conte MM, Pac...
# 1    10639399-1  Northoff G, Richter A, Gessner M, Schlagenhauf...
# 2    10683393-1                     Henson RN, Burgess N, Frith CD
# 3    10686176-1  Engelien A, Huber W, Silbersweig D, Stern E, F...
# 4    10899227-1  Moore CI, Stern CE, Corkin S, Fischl B, Gray A...
# ..          ...                                                ...
# 541  29515382-1  Bloechle J, Huber JF, Klein E, Bahnmueller J, ...
# 542  29518712-1                 McCormick EM, Perino MT, Telzer EH
# 543  29579064-1  Horndasch S, Roesch J, Forster C, Dorfler A, L...
# 544  29729394-1  Strahler J, Kruse O, Wehrum-Osinsky S, Klucken...
# 545  29767302-1                                         Mueller SG
#
#      contrast_id        id.1                                  journal  \
# 0              1  10639391-1  Cerebral cortex (New York, N.Y. : 1991)
# 1              1  10639399-1  Cerebral cortex (New York, N.Y. : 1991)
# 2              1  10683393-1                         Neuropsychologia
# 3              1  10686176-1           Brain : a journal of neurology
# 4              1  10899227-1               Journal of neurophysiology
# ..           ...         ...                                      ...
# 541            1  29515382-1          Frontiers in human neuroscience
# 542            1  29518712-1     Developmental cognitive neuroscience
# 543            1  29579064-1                                 PloS one
# 544            1  29729394-1                               NeuroImage
# 545            1  29767302-1               Brain imaging and behavior
#
#      study_id                                              title  year
# 0    10639391  Visual function and brain organization in non-...  2000
# 1    10639399  Functional dissociation between medial and lat...  2000
# 2    10683393  Recoding, storage, rehearsal and grouping in v...  2000
# 3    10686176  The neural correlates of 'deaf-hearing' in man...  2000
# 4    10899227  Segregation of somatosensory activation in the...  2000
# ..        ...                                                ...   ...
# 541  29515382  Spatial Arrangement and Set Size Influence the...  2018
# 542  29518712  Not just social sensitivity: Adolescent neural...  2018
# 543  29579064  Neural processing of food and emotional stimul...  2018
# 544  29729394  Neural correlates of gender differences in dis...  2018
# 545  29767302  Amyloid causes intermittent network disruption...  2018
#
# [546 rows x 8 columns], 'lMDN':              id                                            authors  \
# 0    10531451-1  Shulman GL, Ollinger JM, Akbudak E, Conturo TE...
# 1    11110834-1  Delgado MR, Nystrom LE, Fissell C, Noll DC, Fi...
# 2    11167053-1  Tracy JI, Faro SS, Mohammed F, Pinus A, Christ...
# 3    11306631-1       Berns GS, McClure SM, Pagnoni G, Montague PR
# 4    11844728-1  Rowe J, Stephan KE, Friston K, Frackowiak R, L...
# ..          ...                                                ...
# 395  29294431-1                     Cogoni C, Carnaghi A, Silani G
# 396  29496614-1  Markello RD, Spreng RN, Luh WM, Anderson AK, D...
# 397  29729394-1  Strahler J, Kruse O, Wehrum-Osinsky S, Klucken...
# 398  29733816-1           Abraham A, Rutter B, Bantin T, Hermann C
# 399   9787003-1  Portas CM, Rees G, Howseman AM, Josephs O, Tur...
#
#      contrast_id        id.1  \
# 0              1  10531451-1
# 1              1  11110834-1
# 2              1  11167053-1
# 3              1  11306631-1
# 4              1  11844728-1
# ..           ...         ...
# 395            1  29294431-1
# 396            1  29496614-1
# 397            1  29729394-1
# 398            1  29733816-1
# 399            1   9787003-1
#
#                                                journal  study_id  \
# 0    The Journal of neuroscience : the official jou...  10531451
# 1                           Journal of neurophysiology  11110834
# 2             Brain research. Cognitive brain research  11167053
# 3    The Journal of neuroscience : the official jou...  11306631
# 4                       Brain : a journal of neurology  11844728
# ..                                                 ...       ...
# 395  Cortex; a journal devoted to the study of the ...  29294431
# 396                                         NeuroImage  29496614
# 397                                         NeuroImage  29729394
# 398                                   Neuropsychologia  29733816
# 399  The Journal of neuroscience : the official jou...   9787003
#
#                                                  title  year
# 0    Areas involved in encoding and applying direct...  1999
# 1    Tracking the hemodynamic responses to reward a...  2000
# 2    A comparison of 'Early' and 'Late' stage brain...  2001
# 3    Predictability modulates human brain response ...  2001
# 4    Attention to action in Parkinson's disease: im...  2002
# ..                                                 ...   ...
# 395  Reduced empathic responses for sexually object...  2018
# 396  Segregation of the human basal forebrain using...  2018
# 397  Neural correlates of gender differences in dis...  2018
# 398  Creative conceptual expansion: A combined fMRI...  2018
# 399  A specific role for the thalamus in mediating ...  1998
#
# [400 rows x 8 columns], 'PFC':               id                                            authors  \
# 0     10216270-1  Lepage M, Beaudoin G, Boulet C, O'Brien I, Mar...
# 1     10356062-1  Gitelman DR, Nobre AC, Parrish TB, LaBar KS, K...
# 2     10531451-1  Shulman GL, Ollinger JM, Akbudak E, Conturo TE...
# 3     10554989-1  Burton H, Abend NS, MacLeod AM, Sinclair RJ, S...
# 4     10554993-1  Grosbras MH, Lobel E, Van de Moortele PF, LeBi...
# ...          ...                                                ...
# 1071   9084599-1  Jueptner M, Stephan KM, Frith CD, Brooks DJ, F...
# 1072   9114263-1  Fink GR, Frackowiak RS, Pietrzyk U, Passingham RE
# 1073   9405692-1  Thompson-Schill SL, D'Esposito M, Aguirre GK, ...
# 1074   9465007-1  Sakai K, Hikosaka O, Miyauchi S, Takino R, Sas...
# 1075   9838166-1  Wildgruber D, Kischka U, Ackermann H, Klose U,...
#
#       contrast_id        id.1  \
# 0               1  10216270-1
# 1               1  10356062-1
# 2               1  10531451-1
# 3               1  10554989-1
# 4               1  10554993-1
# ...           ...         ...
# 1071            1   9084599-1
# 1072            1   9114263-1
# 1073            1   9405692-1
# 1074            1   9465007-1
# 1075            1   9838166-1
#
#                                                 journal  study_id  \
# 0              Brain research. Cognitive brain research  10216270
# 1                        Brain : a journal of neurology  10356062
# 2     The Journal of neuroscience : the official jou...  10531451
# 3               Cerebral cortex (New York, N.Y. : 1991)  10554989
# 4               Cerebral cortex (New York, N.Y. : 1991)  10554993
# ...                                                 ...       ...
# 1071                         Journal of neurophysiology   9084599
# 1072                         Journal of neurophysiology   9114263
# 1073  Proceedings of the National Academy of Science...   9405692
# 1074  The Journal of neuroscience : the official jou...   9465007
# 1075           Brain research. Cognitive brain research   9838166
#
#                                                   title  year
# 0     Frontal cortex and the programming of repetiti...  1999
# 1     A large-scale distributed network for covert s...  1999
# 2     Areas involved in encoding and applying direct...  1999
# 3     Tactile attention tasks enhance activation in ...  1999
# 4     An anatomical landmark for the supplementary e...  1999
# ...                                                 ...   ...
# 1071  Anatomy of motor learning. I. Frontal cortex a...  1997
# 1072  Multiple nonprimary motor areas in the human c...  1997
# 1073  Role of left inferior prefrontal cortex in ret...  1997
# 1074  Transition of brain activation from frontal to...  1998
# 1075  Dynamic pattern of brain activation during seq...  1999
#
# [1076 rows x 8 columns], 'rIFGtri1':              id                                            authors  \
# 0    10689056-1             Coull JT, Frith CD, Buchel C, Nobre AC
# 1    11053230-1  Gerardin E, Sirigu A, Lehericy S, Poline JB, G...
# 2    11133788-1                           Poldrack RA, Gabrieli JD
# 3    11163282-1  Portas CM, Krakow K, Allen P, Josephs O, Armon...
# 4    11516444-1  Maratos EJ, Dolan RJ, Morris JS, Henson RN, Ru...
# ..          ...                                                ...
# 269  29079342-1  Fulford J, Milton F, Salas D, Smith A, Simler ...
# 270  29270356-1  Young KD, Siegle GJ, Misaki M, Zotev V, Philli...
# 271  29420750-1  Morita T, Saito DN, Ban M, Shimada K, Okamoto ...
# 272  29704615-1  Nettekoven C, Reck N, Goldbrunner R, Grefkes C...
# 273  29733816-1           Abraham A, Rutter B, Bantin T, Hermann C
#
#      contrast_id        id.1  \
# 0              1  10689056-1
# 1              1  11053230-1
# 2              1  11133788-1
# 3              1  11163282-1
# 4              1  11516444-1
# ..           ...         ...
# 269            1  29079342-1
# 270            1  29270356-1
# 271            1  29420750-1
# 272            1  29704615-1
# 273            1  29733816-1
#
#                                                journal  study_id  \
# 0                                     Neuropsychologia  10689056
# 1              Cerebral cortex (New York, N.Y. : 1991)  11053230
# 2                       Brain : a journal of neurology  11133788
# 3                                               Neuron  11163282
# 4                                     Neuropsychologia  11516444
# ..                                                 ...       ...
# 269  Cortex; a journal devoted to the study of the ...  29079342
# 270                               NeuroImage. Clinical  29270356
# 271            Cerebral cortex (New York, N.Y. : 1991)  29420750
# 272                                         NeuroImage  29704615
# 273                                   Neuropsychologia  29733816
#
#                                                  title  year
# 0    Orienting attention in time: behavioural and n...  2000
# 1    Partially overlapping neural networks for real...  2000
# 2    Characterizing the neural mechanisms of skill ...  2001
# 3    Auditory processing across the sleep-wake cycl...  2000
# 4    Neural activity associated with episodic memor...  2001
# ..                                                 ...   ...
# 269  The neural correlates of visual imagery vividn...  2017
# 270  Altered task-based and resting-state amygdala ...  2018
# 271  Self-Face Recognition Begins to Share Active R...  2018
# 272  Short- and long-term reliability of language f...  2018
# 273  Creative conceptual expansion: A combined fMRI...  2018
#
# [274 rows x 8 columns], 'rGPi':              id                                            authors  \
# 0    10899227-1  Moore CI, Stern CE, Corkin S, Fischl B, Gray A...
# 1    10906317-1  Vandenberghe R, Duncan J, Arnell KM, Bishop SJ...
# 2    11133788-1                           Poldrack RA, Gabrieli JD
# 3    11163282-1  Portas CM, Krakow K, Allen P, Josephs O, Armon...
# 4    11169874-1                      Liddle PF, Kiehl KA, Smith AM
# ..          ...                                                ...
# 313  29258849-1  Qiao-Tasserit E, Corradi-Dell'Acqua C, Vuilleu...
# 314  29408525-1           Campbell MEJ, Mehrkanoon S, Cunnington R
# 315  29662447-1  Apaydin N, Ustun S, Kale EH, Celikag I, Ozguve...
# 316  29727768-1          Choi EJ, Taylor MJ, Hong SB, Kim C, Yi SH
# 317   9084599-1  Jueptner M, Stephan KM, Frith CD, Brooks DJ, F...
#
#      contrast_id        id.1                                  journal  \
# 0              1  10899227-1               Journal of neurophysiology
# 1              1  10906317-1  Cerebral cortex (New York, N.Y. : 1991)
# 2              1  11133788-1           Brain : a journal of neurology
# 3              1  11163282-1                                   Neuron
# 4              1  11169874-1                      Human brain mapping
# ..           ...         ...                                      ...
# 313            1  29258849-1                         Neuropsychologia
# 314            1  29408525-1                         Neuropsychologia
# 315            1  29662447-1          Frontiers in human neuroscience
# 316            1  29727768-1                      Brain and cognition
# 317            1   9084599-1               Journal of neurophysiology
#
#      study_id                                              title  year
# 0    10899227  Segregation of somatosensory activation in the...  2000
# 1    10906317  Maintaining and shifting attention within left...  2000
# 2    11133788  Characterizing the neural mechanisms of skill ...  2001
# 3    11163282  Auditory processing across the sleep-wake cycl...  2000
# 4    11169874   Event-related fMRI study of response inhibition.  2001
# ..        ...                                                ...   ...
# 313  29258849  The good, the bad, and the suffering. Transien...  2017
# 314  29408525  Intentionally not imitating: Insula cortex eng...  2018
# 315  29662447  Neural Mechanisms Underlying Time Perception a...  2018
# 316  29727768  The neural correlates of attachment security i...  2018
# 317   9084599  Anatomy of motor learning. I. Frontal cortex a...  1997
#
# [318 rows x 8 columns], 'lIFGop7':              id                                            authors  \
# 0    10191322-1                           Chee MW, Tan EW, Thiel T
# 1    10388802-1                    Henson RN, Shallice T, Dolan RJ
# 2    10908201-1  Dupont S, Van de Moortele PF, Samson S, Hasbou...
# 3    11339984-1                           Ferstl EC, von Cramon DY
# 4    11923436-1                            Shelton AL, Gabrieli JD
# ..          ...                                                ...
# 168  29079398-1  Caravaggio F, Fervaha G, Menon M, Remington G,...
# 169  29159044-1  Araneda R, Renier L, Dricot L, Decat M, Ebner-...
# 170  29159055-1  Heinzel S, Kaufmann C, Grutzmann R, Hummel R, ...
# 171  29375348-1   Yang X, Xu J, Cao L, Li X, Wang P, Wang B, Liu B
# 172  29742133-1  Sarabi MT, Aoki R, Tsumura K, Keerativittayayu...
#
#      contrast_id        id.1  \
# 0              1  10191322-1
# 1              1  10388802-1
# 2              1  10908201-1
# 3              1  11339984-1
# 4              1  11923436-1
# ..           ...         ...
# 168            1  29079398-1
# 169            1  29159044-1
# 170            1  29159055-1
# 171            1  29375348-1
# 172            1  29742133-1
#
#                                                journal  study_id  \
# 0    The Journal of neuroscience : the official jou...  10191322
# 1                       Brain : a journal of neurology  10388802
# 2                       Brain : a journal of neurology  10908201
# 3             Brain research. Cognitive brain research  11339984
# 4    The Journal of neuroscience : the official jou...  11923436
# ..                                                 ...       ...
# 168                                   Neuropsychologia  29079398
# 169                               NeuroImage. Clinical  29159044
# 170                               NeuroImage. Clinical  29159055
# 171                    Frontiers in human neuroscience  29375348
# 172                                           PloS one  29742133
#
#                                                  title  year
# 0    Mandarin and English single word processing st...  1999
# 1    Right prefrontal cortex and episodic memory re...  1999
# 2    Episodic memory in left temporal lobe epilepsy...  2000
# 3    The role of coherence and cohesion in text com...  2001
# 4    Neural correlates of encoding space from route...  2002
# ..                                                 ...   ...
# 168  The neural correlates of apathy in schizophren...  2017
# 169  A key role of the prefrontal cortex in the mai...  2018
# 170  Neural correlates of working memory deficits a...  2018
# 171  Linear Representation of Emotions in Whole Per...  2017
# 172  Visual perceptual training reconfigures post-t...  2018
#
# [173 rows x 8 columns], 'lGPi':              id                                            authors  \
# 0    11549618-1                             Parsons LM, Osherson D
# 1    11587890-1  Jessen F, Flacke S, Granath DO, Manka C, Schee...
# 2    12457763-1  Cabeza R, Dolcos F, Prince SE, Rice HJ, Weissm...
# 3    12477696-1  Daselaar SM, Veltman DJ, Rombouts SA, Raaijmak...
# 4    12595181-1  Knutson B, Fong GW, Bennett SM, Adams CM, Homm...
# ..          ...                                                ...
# 305  29109242-1  Chung HK, Sjostrom T, Lee HJ, Lu YT, Tsuo FY, ...
# 306  29408479-1  Zou LQ, Zhou HY, Zhuang Y, van Hartevelt TJ, L...
# 307  29462767-1    Martz ME, Zucker RA, Schulenberg JE, Heitzeg MM
# 308  29654733-1        Wu JJ, Lu YC, Hua XY, Ma SJ, Shan CL, Xu JG
# 309  29753107-1  Reverberi C, Kuhlen AK, Seyed-Allaei S, Greuli...
#
#      contrast_id        id.1  \
# 0              1  11549618-1
# 1              1  11587890-1
# 2              1  12457763-1
# 3              1  12477696-1
# 4              1  12595181-1
# ..           ...         ...
# 305            1  29109242-1
# 306            1  29408479-1
# 307            1  29462767-1
# 308            1  29654733-1
# 309            1  29753107-1
#
#                                                journal  study_id  \
# 0              Cerebral cortex (New York, N.Y. : 1991)  11549618
# 1             Brain research. Cognitive brain research  11587890
# 2                                     Neuropsychologia  12457763
# 3                       Brain : a journal of neurology  12477696
# 4                                           NeuroImage  12595181
# ..                                                 ...       ...
# 305  The Journal of neuroscience : the official jou...  29109242
# 306                                   Neuropsychologia  29408479
# 307                        Drug and alcohol dependence  29462767
# 308                                     Brain research  29654733
# 309                                         NeuroImage  29753107
#
#                                                  title  year
# 0    New Evidence for Distinct Right and Left Brain...  2001
# 1    Encoding and retrieval related cerebral activa...  2001
# 2    Attention-related activity during episodic mem...  2003
# 3    Neuroanatomical correlates of episodic encodin...  2003
# 4    A region of mesial prefrontal cortex tracks mo...  2003
# ..                                                 ...   ...
# 305  Why Do Irrelevant Alternatives Matter? An fMRI...  2017
# 306  Neural responses during the anticipation and r...  2018
# 307  Psychosocial and neural indicators of resilien...  2018
# 308  Cortical remodeling after electroacupuncture t...  2018
# 309  The neural basis of free language choice in bi...  2018
#
# [310 rows x 8 columns], 'rMDN':              id                                            authors  \
# 0    10215087-1                        Elliott R, Rees G, Dolan RJ
# 1    10531451-1  Shulman GL, Ollinger JM, Akbudak E, Conturo TE...
# 2    10594068-1          Buchel C, Dolan RJ, Armony JL, Friston KJ
# 3    11160520-1  Bense S, Stephan T, Yousry TA, Brandt T, Diete...
# 4    11567063-1  Monchi O, Petrides M, Petre V, Worsley K, Dagh...
# ..          ...                                                ...
# 478  29288994-1  Bagarinao E, Maesawa S, Ito Y, Usui N, Natsume...
# 479  29294431-1                     Cogoni C, Carnaghi A, Silani G
# 480  29496614-1  Markello RD, Spreng RN, Luh WM, Anderson AK, D...
# 481  29633199-1        Anderson NE, Maurer JM, Steele VR, Kiehl KA
# 482  29751242-1  Wei Y, Chang M, Womer FY, Zhou Q, Yin Z, Wei S...
#
#      contrast_id        id.1  \
# 0              1  10215087-1
# 1              1  10531451-1
# 2              1  10594068-1
# 3              1  11160520-1
# 4              1  11567063-1
# ..           ...         ...
# 478            1  29288994-1
# 479            1  29294431-1
# 480            1  29496614-1
# 481            1  29633199-1
# 482            1  29751242-1
#
#                                                journal  study_id  \
# 0                                     Neuropsychologia  10215087
# 1    The Journal of neuroscience : the official jou...  10531451
# 2    The Journal of neuroscience : the official jou...  10594068
# 3                           Journal of neurophysiology  11160520
# 4    The Journal of neuroscience : the official jou...  11567063
# ..                                                 ...       ...
# 478  Clinical neurophysiology : official journal of...  29288994
# 479  Cortex; a journal devoted to the study of the ...  29294431
# 480                                         NeuroImage  29496614
# 481     Cognitive, affective & behavioral neuroscience  29633199
# 482                     Journal of affective disorders  29751242
#
#                                                  title  year
# 0    Ventromedial prefrontal cortex mediates guessing.  1999
# 1    Areas involved in encoding and applying direct...  1999
# 2    Amygdala-hippocampal involvement in human aver...  1999
# 3    Multisensory cortical signal increases and dec...  2001
# 4    Wisconsin Card Sorting revisited: distinct neu...  2001
# ..                                                 ...   ...
# 478  Detecting sub-second changes in brain activati...  2017
# 479  Reduced empathic responses for sexually object...  2018
# 480  Segregation of the human basal forebrain using...  2018
# 481  Psychopathic traits associated with abnormal h...  2018
# 482  Local functional connectivity alterations in s...  2018
#
# [483 rows x 8 columns], 'lCaud33':              id                                            authors  \
# 0    10022492-1  Callicott JH, Mattay VS, Bertolino A, Finn K, ...
# 1    10376114-1  Bush G, Frazier JA, Rauch SL, Seidman LJ, Whal...
# 2    11567063-1  Monchi O, Petrides M, Petre V, Worsley K, Dagh...
# 3    11590110-1                                  Chein JM, Fiez JA
# 4    12077007-1  MacSweeney M, Woll B, Campbell R, McGuire PK, ...
# ..          ...                                                ...
# 302  29175202-1         Moreno A, Limousin F, Dehaene S, Pallier C
# 303  29408479-1  Zou LQ, Zhou HY, Zhuang Y, van Hartevelt TJ, L...
# 304  29462767-1    Martz ME, Zucker RA, Schulenberg JE, Heitzeg MM
# 305  29579064-1  Horndasch S, Roesch J, Forster C, Dorfler A, L...
# 306  29731712-1  Ren Z, Liu Y, Li K, Duan Y, Jing H, Liang P, S...
#
#      contrast_id        id.1  \
# 0              1  10022492-1
# 1              1  10376114-1
# 2              1  11567063-1
# 3              1  11590110-1
# 4              1  12077007-1
# ..           ...         ...
# 302            1  29175202-1
# 303            1  29408479-1
# 304            1  29462767-1
# 305            1  29579064-1
# 306            1  29731712-1
#
#                                                journal  study_id  \
# 0              Cerebral cortex (New York, N.Y. : 1991)  10022492
# 1                                Biological psychiatry  10376114
# 2    The Journal of neuroscience : the official jou...  11567063
# 3              Cerebral cortex (New York, N.Y. : 1991)  11590110
# 4                       Brain : a journal of neurology  12077007
# ..                                                 ...       ...
# 302                                         NeuroImage  29175202
# 303                                   Neuropsychologia  29408479
# 304                        Drug and alcohol dependence  29462767
# 305                                           PloS one  29579064
# 306                    Frontiers in human neuroscience  29731712
#
#                                                  title  year
# 0    Physiological characteristics of capacity cons...  1999
# 1    Anterior cingulate cortex dysfunction in atten...  1999
# 2    Wisconsin Card Sorting revisited: distinct neu...  2001
# 3    Dissociation of verbal working memory system c...  2001
# 4    Neural systems underlying British Sign Languag...  2002
# ..                                                 ...   ...
# 302  Brain correlates of constituent structure in s...  2018
# 303  Neural responses during the anticipation and r...  2018
# 304  Psychosocial and neural indicators of resilien...  2018
# 305  Neural processing of food and emotional stimul...  2018
# 306  Baseline Brain Activity Changes in Patients Wi...  2018
#
# [307 rows x 8 columns]}

# %%
def compare_rois_and_save_csv(roi_names, output_csv_path=None):
    """
    Given a list of ROI names (matching subfolder names in derivatives/macm),
    find the intersection of their study IDs and save as a new CSV.
    If output_csv_path is not provided, it will be named automatically as 'roi1-roi2-...-studies.csv'.
    """
    # Load DataFrames for the specified ROIs
    dfs = []
    for roi in roi_names:
        csv_path = op.join(macm_dir, roi, f"{roi}_studies.csv")
        if not op.exists(csv_path):
            print(f"CSV not found for ROI: {roi}")
            return
        df = pd.read_csv(csv_path)
        dfs.append(df)
    # Find intersection of IDs
    common_ids = set(dfs[0]['id'])
    for df in dfs[1:]:
        common_ids &= set(df['id'])
    print(f"Found {len(common_ids)} common study IDs for ROIs: {roi_names}")
    # Optionally, merge metadata from the first ROI
    if common_ids:
        merged = dfs[0][dfs[0]['id'].isin(common_ids)].copy()
        if output_csv_path is None:
            roi_part = '-'.join(roi_names)
            output_csv_path = f"derivatives/macm/{roi_part}-studies.csv"
        merged.to_csv(output_csv_path, index=False)
        print(f"Saved intersection CSV to {output_csv_path}")
    else:
        print("No common study IDs found.")

def compare_all_rois_and_save_csv():
    """
    Find the intersection of study IDs across all ROI CSVs and save as 9ROIs-studies.csv.
    """
    roi_names = [f for f in os.listdir(macm_dir) if op.isdir(op.join(macm_dir, f))]
    if not roi_names:
        print("No ROI folders found in macm_dir.")
        return
    compare_rois_and_save_csv(roi_names, output_csv_path="derivatives/macm/9ROIs-studies.csv")

# %%
compare_all_rois_and_save_csv()
# Out:
# Found 0 common study IDs for ROIs: ['rCaud31', 'lMDN', 'PFC', 'rIFGtri1', 'rGPi', 'lIFGop7', 'lGPi', 'rMDN', 'lCaud33']
# No common study IDs found.

# %%
compare_rois_and_save_csv(['PFC', 'lMDN', 'rMDN','lGPi', 'rGPi', 'rCaud31', 'lCaud33'])
# Out:
# Found 0 common study IDs for ROIs: ['PFC', 'lMDN', 'rMDN', 'lGPi', 'rGPi', 'rCaud31', 'lCaud33']
# No common study IDs found.

# %%
compare_rois_and_save_csv(['PFC', 'lMDN', 'rMDN','lGPi', 'rGPi'])
# Out:
# Found 1 common study IDs for ROIs: ['PFC', 'lMDN', 'rMDN', 'lGPi', 'rGPi']
# Saved intersection CSV to derivatives/macm/PFC-lMDN-rMDN-lGPi-rGPi-studies.csv

# %%
compare_rois_and_save_csv(['PFC', 'rCaud31', 'lCaud33'])
# Out:
# Found 16 common study IDs for ROIs: ['PFC', 'rCaud31', 'lCaud33']
# Saved intersection CSV to derivatives/macm/PFC-rCaud31-lCaud33-studies.csv

# %%
compare_rois_and_save_csv(['PFC', 'lIFGop7', 'rIFGtri1'])
# Out:
# Found 2 common study IDs for ROIs: ['PFC', 'lIFGop7', 'rIFGtri1']
# Saved intersection CSV to derivatives/macm/PFC-lIFGop7-rIFGtri1-studies.csv
